# %% [markdown]
# <a href="https://colab.research.google.com/github/ggj0228/practicePyton/blob/main/practiceMath.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

x = symbols('x')
f = 2*x +1
plot(f)

# %%
from sympy import *

x = symbols('x')
f = x **2 + 1
plot(f)

# %%
from sympy import *
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2 * x + 3 * y
plot3d(f)
